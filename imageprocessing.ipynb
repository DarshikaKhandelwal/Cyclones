# %% [markdown]
# <a href="https://colab.research.google.com/github/DarshikaKhandelwal/Cyclones/blob/main/imageprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch torchvision torchaudio

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r /content/yolov5/requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
import uuid   # Unique identifier
import os

# %%
IMAGES_PATH = os.path.join('data', 'images')
labels = ['cyclone eye']
number_imgs = 328

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data/images/cyclone eye.69b379b8-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b37d00-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b37f12-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b380f2-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b382b4-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b38458-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b38606-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b387b4-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b389d0-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b38ba6-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b38d68-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b38f2a-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b391dc-1afb-11ee-a825-0242ac1c000c.jpg
# ...
# data/images/cyclone eye.69b393a8-1afb-11ee-a825-0242ac1c000c.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-192-g459dd49 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5','custom',path='/content/yolov5/runs/train/exp/weights/last.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-7-5 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
img = "/content/biparjoy_cyclone_1686700668660_1686700713616 (1).jpg"

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 309x380 2 cyclones
# Speed: 8.5ms pre-process, 56.0ms inference, 1.5ms NMS per image at shape (1, 3, 544, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
